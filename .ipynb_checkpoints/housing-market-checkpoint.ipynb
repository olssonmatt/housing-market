# %%
#Importing packages, testing APIs, etc.
import requests
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
response = requests.get('https://www.bankofcanada.ca/valet/observations/v41690973/csv')
print(response)
# Out:
# <Response [200]>

# %%
#Gathering data
#Bank of Canada Data
#https://www.bankofcanada.ca/valet/docs
total_cpi = requests.get('https://www.bankofcanada.ca/valet/observations/v41690973/json').json()
nominal_gdp = requests.get('https://www.bankofcanada.ca/valet/series/SAN_2017_21_GDP_V62305783/json').json()
bank_int_rate = requests.get('https://www.bankofcanada.ca/valet/observations/V122530/json').json()
prime_rate = requests.get('https://www.bankofcanada.ca/valet/observations/V122495/json').json()
total_debt_service_ratio = requests.get('https://www.bankofcanada.ca/valet/series/FSR_2016Dec_c2s3/json').json()
debt_to_asset_service_ratio = requests.get('https://www.bankofcanada.ca/valet/series/FSR_2016Dec_c2s2/json').json()
retail_debt = requests.get('https://www.bankofcanada.ca/valet/series/V37295/json').json()
labour_shortage = requests.get('https://www.bankofcanada.ca/valet/observations/INDINF_SLSALLSEC_Q/json').json()
labour_force_survey = requests.get('https://www.bankofcanada.ca/valet/series/INDINF_LFSWC_Q/json').json()
productivity = requests.get('https://www.bankofcanada.ca/valet/series/INDINF_PAWC_Q/json').json()
housing_price_index = requests.get('https://www.bankofcanada.ca/valet/series/INDINF_NHPI_Q/json').json()
housing_affordability_index = requests.get('https://www.bankofcanada.ca/valet/series/INDINF_AFFORD/json').json()
FXMCNYCAD = requests.get('https://www.bankofcanada.ca/valet/observations/FXMCNYCAD/json').json()
FXMEURCAD = requests.get('https://www.bankofcanada.ca/valet/observations/FXMEURCAD/json').json()
FXMJPYCAD = requests.get('https://www.bankofcanada.ca/valet/observations/FXMJPYCAD/json').json()
FXMINRCAD = requests.get('https://www.bankofcanada.ca/valet/observations/FXMINRCAD/json').json()
FXMRUBCAD = requests.get('https://www.bankofcanada.ca/valet/observations/FXMRUBCAD/json').json()
FXMGBPCAD = requests.get('https://www.bankofcanada.ca/valet/observations/FXMGBPCAD/json').json()
FXMUSDCAD = requests.get('https://www.bankofcanada.ca/valet/observations/FXMUSDCAD/json').json()

df = pd.json_normalize(FXMUSDCAD, record_path = ['observations'])
print(df.to_string())

#StatsCan Data
#https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1110023901
canada_total_income = pd.read_csv('./datasets/canada_total_income_organized.csv')
canada_2534_total_income = pd.read_csv('./datasets/canada_2534_total_income_organized.csv')
canada_selfemployed_income = pd.read_csv('./datasets/canada_selfemployed_income_organized.csv')


#Teranet and National Bank of Canada Data
#https://housepriceindex.ca/#maps=c11
house_price_index = pd.read_csv('./datasets/TNBOC_House_Price_Index.csv')
# Out:
#              d FXMUSDCAD.v
# 0   2017-01-01      1.3193
# 1   2017-02-01      1.3107
# 2   2017-03-01      1.3386
# 3   2017-04-01      1.3440
# 4   2017-05-01      1.3607
# 5   2017-06-01      1.3298
# 6   2017-07-01      1.2689
# 7   2017-08-01      1.2605
# 8   2017-09-01      1.2283
# 9   2017-10-01      1.2605
# 10  2017-11-01      1.2769
# 11  2017-12-01      1.2771
# 12  2018-01-01      1.2427
# 13  2018-02-01      1.2586
# 14  2018-03-01      1.2932
# 15  2018-04-01      1.2733
# 16  2018-05-01      1.2873
# 17  2018-06-01      1.3129
# 18  2018-07-01      1.3130
# 19  2018-08-01      1.3041
# 20  2018-09-01      1.3037
# 21  2018-10-01      1.3010
# 22  2018-11-01      1.3200
# 23  2018-12-01      1.3432
# 24  2019-01-01      1.3301
# 25  2019-02-01      1.3206
# 26  2019-03-01      1.3368
# 27  2019-04-01      1.3378
# 28  2019-05-01      1.3459
# 29  2019-06-01      1.3287
# 30  2019-07-01      1.3101
# 31  2019-08-01      1.3277
# 32  2019-09-01      1.3241
# 33  2019-10-01      1.3190
# 34  2019-11-01      1.3239
# 35  2019-12-01      1.3172
# 36  2020-01-01      1.3087
# 37  2020-02-01      1.3286
# 38  2020-03-01      1.3953
# 39  2020-04-01      1.4058
# 40  2020-05-01      1.3970
# 41  2020-06-01      1.3550
# 42  2020-07-01      1.3499
# 43  2020-08-01      1.3222
# 44  2020-09-01      1.3228
# 45  2020-10-01      1.3215
# 46  2020-11-01      1.3068
# 47  2020-12-01      1.2808
# 48  2021-01-01      1.2724
# 49  2021-02-01      1.2699
# 50  2021-03-01      1.2574
# 51  2021-04-01      1.2496
# 52  2021-05-01      1.2126
# 53  2021-06-01      1.2219
# 54  2021-07-01      1.2529
# 55  2021-08-01      1.2603
# 56  2021-09-01      1.2671
# 57  2021-10-01      1.2437
# 58  2021-11-01      1.2570
# 59  2021-12-01      1.2794
# 60  2022-01-01      1.2616
# 61  2022-02-01      1.2716
# 62  2022-03-01      1.2658
# 63  2022-04-01      1.2628
# 64  2022-05-01      1.2852
# 65  2022-06-01      1.2814
# 66  2022-07-01      1.2942
# 67  2022-08-01      1.2922
# 68  2022-09-01      1.3319
# 69  2022-10-01      1.3700
# 70  2022-11-01      1.3449
# 71  2022-12-01      1.3592
# 72  2023-01-01      1.3422
# 73  2023-02-01      1.3450
# 74  2023-03-01      1.3682
# 75  2023-04-01      1.3485

# %%
fig, ax = plt.subplots()
ax.scatter(xt,yt,
           s=1,
           marker='1',
           c='slategrey',
           alpha=1)
ax.plot(xt,yt,
           c='slategrey',
           alpha=0.05)
ax.grid(c='whitesmoke',alpha=0.5)
ax.set_facecolor('w')
ax.spines['top'].set_color('whitesmoke')
ax.spines['bottom'].set_color('whitesmoke')
ax.spines['left'].set_color('whitesmoke')
ax.spines['right'].set_color('whitesmoke')
ax.tick_params(axis='x', colors='lightgray')
ax.tick_params(axis='y', colors='lightgray')
#plt.xlim([-0.04,0.025])
#plt.ylim([-0.01,0.02])
plt.show()
